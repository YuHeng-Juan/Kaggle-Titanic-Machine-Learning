# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-a71366cb-14d6-4b3d-9813-95bdd5f5f6f0" name="files[]" multiple disabled />
#      <output id="result-a71366cb-14d6-4b3d-9813-95bdd5f5f6f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
from google.colab import files
upload2 = files.upload()
# Out:
#      <input type="file" id="files-3b0ba359-9d87-4a3e-a076-1d9ead04dee0" name="files[]" multiple disabled />
#      <output id="result-3b0ba359-9d87-4a3e-a076-1d9ead04dee0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
df = pandas.read_csv("train.csv")
df2 = pandas.read_csv('test.csv')

# %%
import numpy as np
import pandas
df = pandas.read_csv("train.csv")
df2 = pandas.read_csv('test.csv')
df['Age'] = df['Age'].fillna(df["Age"].median())
df['Fare'] = df["Fare"].fillna(df['Fare'].median())
df = df.fillna(0)
df['Title'] = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')
df['Title'] = df['Title'].replace('Mr',1)
df['Title'] = df['Title'].replace('Miss',2)
df['Title'] = df['Title'].replace('Mrs',3)
df['Title'] = df['Title'].replace('Master',4)
df['Title'] = df['Title'].replace('Rare',5)

df.drop("Name",axis=1, inplace=True)
df.drop("Ticket",axis=1, inplace=True)
df.drop('Cabin', axis=1, inplace=True)
df["FamilySize"] = df["SibSp"] + df["Parch"]+1
df['IsAlone'] = 0
df.loc[df['FamilySize'] == 1, 'IsAlone'] = 1
df.drop('SibSp', axis=1, inplace=True)
df.drop('Parch', axis=1, inplace=True)
df.drop('FamilySize', axis=1, inplace=True)
df=df.replace('male',0)
df=df.replace('female',1)
df=df.replace('S',0)
df=df.replace('C',1)
df=df.replace('Q',2)

df.loc[ df['Fare'] <= 7.91, 'Fare'] = 0
df.loc[(df['Fare'] > 7.91) & (df['Fare'] <= 14.454), 'Fare'] = 1
df.loc[(df['Fare'] > 14.454) & (df['Fare'] <= 31), 'Fare'] = 2
df.loc[ df['Fare'] > 31, 'Fare'] = 3
df['Fare'] = df['Fare'].astype(int)

df.loc[ df['Age'] <= 16, 'Age'] = 0
df.loc[(df['Age'] > 16) & (df['Age'] <= 32), 'Age'] = 1
df.loc[(df['Age'] > 32) & (df['Age'] <= 48), 'Age'] = 2
df.loc[(df['Age'] > 48) & (df['Age'] <= 64), 'Age'] = 3
df.loc[ df['Age'] > 64, 'Age'] = 4  

#df['Age*Class'] = df.Age * df.Pclass
df2['Age'] = df2['Age'].fillna(df2["Age"].mean())
df2['Fare'] = df2["Fare"].fillna(df2['Fare'].median())
df2 = df2.fillna(0)
df2['Title'] = df2.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
df2['Title'] = df2['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
df2['Title'] = df2['Title'].replace('Mlle', 'Miss')
df2['Title'] = df2['Title'].replace('Ms', 'Miss')
df2['Title'] = df2['Title'].replace('Mme', 'Mrs')
df2['Title'] = df2['Title'].replace('Mr',1)
df2['Title'] = df2['Title'].replace('Miss',2)
df2['Title'] = df2['Title'].replace('Mrs',3)
df2['Title'] = df2['Title'].replace('Master',4)
df2['Title'] = df2['Title'].replace('Rare',5)
df2.drop("Name",axis=1, inplace=True)
df2.drop("Ticket",axis=1, inplace=True)
df2.drop('Cabin', axis=1, inplace=True)
df2["FamilySize"] = df2["SibSp"] + df2["Parch"]+1
df2['IsAlone'] = 0
df2.loc[df2['FamilySize'] == 1, 'IsAlone'] = 1
df2.drop('SibSp', axis=1, inplace=True)
df2.drop('Parch', axis=1, inplace=True)
df2.drop('FamilySize', axis=1, inplace=True)
df2=df2.replace('male',0)
df2=df2.replace('female',1)
df2=df2.replace('S',0)
df2=df2.replace('C',1)
df2=df2.replace('Q',2)



df2.loc[ df2['Fare'] <= 7.91, 'Fare'] = 0
df2.loc[(df2['Fare'] > 7.91) & (df2['Fare'] <= 14.454), 'Fare'] = 1
df2.loc[(df2['Fare'] > 14.454) & (df2['Fare'] <= 31), 'Fare'] = 2
df2.loc[ df2['Fare'] > 31, 'Fare'] = 3
df2['Fare'] = df2['Fare'].astype(int)

df2.loc[ df2['Age'] <= 16, 'Age'] = 0
df2.loc[(df2['Age'] > 16) & (df2['Age'] <= 32), 'Age'] = 1
df2.loc[(df2['Age'] > 32) & (df2['Age'] <= 48), 'Age'] = 2
df2.loc[(df2['Age'] > 48) & (df2['Age'] <= 64), 'Age'] = 3
df2.loc[ df2['Age'] > 64, 'Age'] = 4  

#df2['Age*Class'] = df2.Age * df2.Pclass

#print(df.head(10))
print(df.head(5))
print(df2.head(5))

x_train = df.iloc[0:,2:]
y_train = df.iloc[0:,1:2]
x_test = df2.iloc[0:,1:]


x_train=np.array(x_train)
x_test = np.array(x_test)
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone
# 0            1         0       3    0  1.0     0         0      1        0
# 1            2         1       1    1  2.0     3         1      3        0
# 2            3         1       3    1  1.0     1         0      2        1
# 3            4         1       1    1  2.0     3         0      3        0
# 4            5         0       3    0  2.0     1         0      1        1
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone
# 0          892       3    0  2.0     0         2      1        1
# 1          893       3    1  2.0     0         0      3        0
# 2          894       2    0  3.0     1         2      1        1
# 3          895       3    0  1.0     1         0      1        1
# 4          896       3    1  1.0     1         0      3        0

# %%
# !pip install openpyxl
# Out:
# ...
#     100% |████████████████████████████████| 174kB 6.3MB/s
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/d3/75/83/415a5bbed8366f66a87f7bd0fc28f7df6e13982960f3e5a7ab
# done
#   Stored in directory: /content/.cache/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# ...

# %%
from sklearn.svm import SVC
candidate_classifier = SVC()
candidate_classifier.fit(x_train, y_train)
result = candidate_classifier.predict(x_test)

acc_svc = round(candidate_classifier.score(x_train, y_train) * 100, 2)
print(acc_svc)


new = pandas.DataFrame(result)
print(new)
new.to_excel("new.xlsx","A_sheet",index=False)
# Out:
# 83.39
#      0
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# 5    0
# 6    1
# 7    0
# 8    1
# 9    0
# 10   0
# 11   0
# 12   1
# 13   0
# 14   1
# 15   1
# 16   0
# 17   0
# 18   0
# 19   1
# 20   0
# 21   1
# 22   1
# 23   0
# 24   1
# 25   0
# 26   1
# 27   0
# 28   0
# 29   0
# ..  ..
# 388  0
# 389  0
# 390  0
# 391  1
# 392  0
# 393  0
# 394  0
# 395  1
# 396  0
# 397  1
# 398  0
# 399  0
# 400  1
# 401  0
# 402  1
# 403  0
# 404  0
# 405  0
# 406  0
# 407  0
# 408  1
# 409  1
# 410  1
# 411  1
# 412  1
# 413  0
# 414  1
# 415  0
# 416  0
# 417  0
#
# [418 rows x 1 columns]

# %%
download = files.download("new.xlsx")
